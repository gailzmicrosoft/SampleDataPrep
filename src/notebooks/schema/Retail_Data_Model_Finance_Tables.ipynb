# %%
# Generated CREATE TABLE Statements - Specified Tables
# Generated on: 2025-07-30 21:49:43
# Target schema: retail_simple

# Configuration
SCHEMA_NAME = "retail_simple"
spark.sql(f"CREATE DATABASE IF NOT EXISTS {SCHEMA_NAME}")
print(f"✅ {SCHEMA_NAME} schema ready!")

# 1. Create Ledger table
create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {SCHEMA_NAME}.Ledger (
    LedgerId STRING,
    LedgerName STRING,
    LedgerDescription STRING,
    LegalEntityId STRING,
    LedgerTypeId STRING,
    AccountingFrameworkId STRING
)
USING DELTA
"""
spark.sql(create_table_sql)
print(f"✅ {SCHEMA_NAME}.Ledger table created!")

# 2. Create LedgerAccount table
create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {SCHEMA_NAME}.LedgerAccount (
    LedgerId STRING,
    LedgerAccountNumber STRING,
    LedgerAccountName STRING,
    LedgerAccountCreatedTimestamp TIMESTAMP,
    LedgerAccountOpeningBalanceDate DATE,
    OpeningBalanceAmount DECIMAL(18,2),
    SubaccountIndicator BOOLEAN,
    CustomerId STRING,
    CustomerAccountId STRING,
    AccountsPayableLegalEntityId STRING,
    ProjectId STRING,
    ResponsibilityCenterId STRING,
    LedgerAccountCategoryId STRING,
    LedgerAccountTypeId STRING,
    IsoCurrencyCode STRING
)
USING DELTA
"""
spark.sql(create_table_sql)
print(f"✅ {SCHEMA_NAME}.LedgerAccount table created!")

# 3. Create LedgerAccountCategory table
create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {SCHEMA_NAME}.LedgerAccountCategory (
    LedgerAccountCategoryId STRING,
    LedgerAccountCategoryName STRING,
    LedgerAccountCategoryDescription STRING
)
USING DELTA
"""
spark.sql(create_table_sql)
print(f"✅ {SCHEMA_NAME}.LedgerAccountCategory table created!")

# 4. Create LedgerAccountType table
create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {SCHEMA_NAME}.LedgerAccountType (
    LedgerAccountTypeId STRING,
    LedgerAccountTypeName STRING,
    LedgerAccountTypeDescription STRING
)
USING DELTA
"""
spark.sql(create_table_sql)
print(f"✅ {SCHEMA_NAME}.LedgerAccountType table created!")

# 5. Create LedgerType table
create_table_sql = f"""
CREATE TABLE IF NOT EXISTS {SCHEMA_NAME}.LedgerType (
    LedgerTypeId STRING,
    LedgerTypeName STRING,
    LedgerTypeDescription STRING
)
USING DELTA
"""
spark.sql(create_table_sql)
print(f"✅ {SCHEMA_NAME}.LedgerType table created!")
